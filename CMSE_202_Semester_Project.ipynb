# %% [markdown]
# # CMSE 202 Semester Project

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
url = 'https://raw.githubusercontent.com/dataquestio/project-walkthroughs/master/football_matches/matches.csv'

matches = pd.read_csv(url, index_col=0)

# %%
matches["team"].value_counts()
# Out:
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: team, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W  4.0
# 2   2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away      W  2.0
# 4   2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home      W  3.0
# 6   2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L  2.0
# 7   2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D  2.0
# 9   2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 11  2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W  2.0
# 13  2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D  1.0
# 14  2020-11-22  19:15  Premier League   Matchweek 9  Sun  Home      W  3.0
# 16  2020-11-28  12:30  Premier League  Matchweek 10  Sat  Away      D  1.0
# 18  2020-12-06  19:15  Premier League  Matchweek 11  Sun  Home      W  4.0
# 20  2020-12-13  16:30  Premier League  Matchweek 12  Sun  Away      D  1.0
# 21  2020-12-16  20:00  Premier League  Matchweek 13  Wed  Home      W  2.0
# 22  2020-12-19  12:30  Premier League  Matchweek 14  Sat  Away      W  7.0
# 23  2020-12-27  16:30  Premier League  Matchweek 15  Sun  Home      D  1.0
# 24  2020-12-30  20:00  Premier League  Matchweek 16  Wed  Away      D  0.0
# 25  2021-01-04  20:00  Premier League  Matchweek 17  Mon  Away      L  0.0
# 27  2021-01-17  16:30  Premier League  Matchweek 19  Sun  Home      D  0.0
# 28  2021-01-21  20:00  Premier League  Matchweek 18  Thu  Home      L  0.0
# 30  2021-01-28  20:00  Premier League  Matchweek 20  Thu  Away      W  3.0
# 31  2021-01-31  16:30  Premier League  Matchweek 21  Sun  Away      W  3.0
# 32  2021-02-03  20:15  Premier League  Matchweek 22  Wed  Home      L  0.0
# 33  2021-02-07  16:30  Premier League  Matchweek 23  Sun  Home      L  1.0
# 34  2021-02-13  12:30  Premier League  Matchweek 24  Sat  Away      L  1.0
# 36  2021-02-20  17:30  Premier League  Matchweek 25  Sat  Home      L  0.0
# 37  2021-02-28  19:15  Premier League  Matchweek 26  Sun  Away      W  2.0
# 38  2021-03-04  20:15  Premier League  Matchweek 29  Thu  Home      L  0.0
# 39  2021-03-07  14:00  Premier League  Matchweek 27  Sun  Home      L  0.0
# 41  2021-03-15  20:00  Premier League  Matchweek 28  Mon  Away      W  1.0
# 42  2021-04-03  20:00  Premier League  Matchweek 30  Sat  Away      W  3.0
# 44  2021-04-10  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 46  2021-04-19  20:00  Premier League  Matchweek 32  Mon  Away      D  1.0
# 47  2021-04-24  12:30  Premier League  Matchweek 33  Sat  Home      D  1.0
# 48  2021-05-08  20:15  Premier League  Matchweek 35  Sat  Home      W  2.0
# 49  2021-05-13  20:15  Premier League  Matchweek 34  Thu  Away      W  4.0
# 50  2021-05-16  16:30  Premier League  Matchweek 36  Sun  Away      W  2.0
# 51  2021-05-19  20:15  Premier League  Matchweek 37  Wed  Away      W  3.0
# 52  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  2.0
#
#      ga         opponent  ...  match report  notes    sh   sot  dist   fk  \
# 1   3.0     Leeds United  ...  Match Report    NaN  20.0   4.0  17.0  0.0
# 2   0.0          Chelsea  ...  Match Report    NaN  17.0   5.0  17.7  1.0
# 4   1.0          Arsenal  ...  Match Report    NaN  21.0   9.0  16.8  0.0
# 6   7.0      Aston Villa  ...  Match Report    NaN  14.0   8.0  15.8  1.0
# 7   2.0          Everton  ...  Match Report    NaN  22.0   8.0  15.0  1.0
# 9   1.0    Sheffield Utd  ...  Match Report    NaN  17.0   5.0  18.2  1.0
# 11  1.0         West Ham  ...  Match Report    NaN   8.0   2.0  18.6  1.0
# 13  1.0  Manchester City  ...  Match Report    NaN   9.0   2.0  21.5  0.0
# 14  0.0   Leicester City  ...  Match Report    NaN  24.0  12.0  11.9  0.0
# 16  1.0         Brighton  ...  Match Report    NaN   6.0   2.0  20.9  0.0
# 18  0.0           Wolves  ...  Match Report    NaN  11.0   6.0  16.6  1.0
# 20  1.0           Fulham  ...  Match Report    NaN  11.0   5.0  20.0  1.0
# 21  1.0        Tottenham  ...  Match Report    NaN  17.0  11.0  15.5  0.0
# 22  0.0   Crystal Palace  ...  Match Report    NaN  14.0   7.0  13.2  1.0
# 23  1.0        West Brom  ...  Match Report    NaN  17.0   2.0  17.8  2.0
# 24  0.0    Newcastle Utd  ...  Match Report    NaN  11.0   4.0  16.7  0.0
# 25  1.0      Southampton  ...  Match Report    NaN  17.0   1.0  14.3  0.0
# 27  0.0   Manchester Utd  ...  Match Report    NaN  17.0   3.0  17.1  0.0
# 28  1.0          Burnley  ...  Match Report    NaN  27.0   6.0  17.3  0.0
# 30  1.0        Tottenham  ...  Match Report    NaN  14.0   7.0  14.7  0.0
# 31  1.0         West Ham  ...  Match Report    NaN  14.0   5.0  15.3  0.0
# 32  1.0         Brighton  ...  Match Report    NaN  11.0   0.0  19.9  0.0
# 33  4.0  Manchester City  ...  Match Report    NaN   7.0   2.0  17.9  1.0
# 34  3.0   Leicester City  ...  Match Report    NaN  15.0   4.0  15.4  2.0
# 36  2.0          Everton  ...  Match Report    NaN  16.0   6.0  15.9  1.0
# 37  0.0    Sheffield Utd  ...  Match Report    NaN  15.0   8.0  14.2  0.0
# 38  1.0          Chelsea  ...  Match Report    NaN   7.0   1.0  18.4  0.0
# 39  1.0           Fulham  ...  Match Report    NaN  16.0   3.0  17.0  1.0
# 41  0.0           Wolves  ...  Match Report    NaN  12.0   4.0  15.9  0.0
# 42  0.0          Arsenal  ...  Match Report    NaN  16.0   7.0  17.0  0.0
# 44  1.0      Aston Villa  ...  Match Report    NaN  23.0   8.0  16.7  1.0
# 46  1.0     Leeds United  ...  Match Report    NaN  17.0   7.0  15.7  0.0
# 47  1.0    Newcastle Utd  ...  Match Report    NaN  21.0   9.0  17.0  1.0
# 48  0.0      Southampton  ...  Match Report    NaN  14.0   6.0  12.4  0.0
# 49  2.0   Manchester Utd  ...  Match Report    NaN  17.0   8.0  14.9  0.0
# 50  1.0        West Brom  ...  Match Report    NaN  26.0   6.0  16.9  1.0
# 51  0.0          Burnley  ...  Match Report    NaN  20.0   3.0  15.5  1.0
# 52  0.0   Crystal Palace  ...  Match Report    NaN  19.0   5.0  14.2  1.0
#
#      pk pkatt  season       team
# 1   2.0   2.0    2021  Liverpool
# 2   0.0   0.0    2021  Liverpool
# 4   0.0   0.0    2021  Liverpool
# 6   0.0   0.0    2021  Liverpool
# 7   0.0   0.0    2021  Liverpool
# 9   0.0   0.0    2021  Liverpool
# 11  1.0   1.0    2021  Liverpool
# 13  1.0   1.0    2021  Liverpool
# 14  0.0   0.0    2021  Liverpool
# 16  0.0   0.0    2021  Liverpool
# 18  0.0   0.0    2021  Liverpool
# 20  1.0   1.0    2021  Liverpool
# 21  0.0   0.0    2021  Liverpool
# 22  0.0   0.0    2021  Liverpool
# 23  0.0   0.0    2021  Liverpool
# 24  0.0   0.0    2021  Liverpool
# 25  0.0   0.0    2021  Liverpool
# 27  0.0   0.0    2021  Liverpool
# 28  0.0   0.0    2021  Liverpool
# 30  0.0   0.0    2021  Liverpool
# 31  0.0   0.0    2021  Liverpool
# 32  0.0   0.0    2021  Liverpool
# 33  1.0   1.0    2021  Liverpool
# 34  0.0   0.0    2021  Liverpool
# 36  0.0   0.0    2021  Liverpool
# 37  0.0   0.0    2021  Liverpool
# 38  0.0   0.0    2021  Liverpool
# 39  0.0   0.0    2021  Liverpool
# 41  0.0   0.0    2021  Liverpool
# 42  0.0   0.0    2021  Liverpool
# 44  0.0   0.0    2021  Liverpool
# 46  0.0   0.0    2021  Liverpool
# 47  0.0   0.0    2021  Liverpool
# 48  0.0   0.0    2021  Liverpool
# 49  0.0   0.0    2021  Liverpool
# 50  0.0   0.0    2021  Liverpool
# 51  0.0   0.0    2021  Liverpool
# 52  0.0   0.0    2021  Liverpool
#
# [38 rows x 27 columns]

# %%
del matches["comp"]
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2022-01-01']
test = matches[matches["date"] > '2022-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])
accuracy = accuracy_score(test["target"], preds)
accuracy
# Out:
# 0.6123188405797102

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))
precision_score(test["target"], preds)
# Out:
# 0.4745762711864407

# %%
grouped_matches = matches.groupby("team")
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group
cols = ["gf", "ga", "sh", "sot","dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling[matches_rolling['team']=='Liverpool']
# Out:
#                    date   time         round  day venue result   gf   ga  \
# team
# Liverpool 6  2020-10-04  19:15   Matchweek 4  Sun  Away      L  2.0  7.0
#           7  2020-10-17  12:30   Matchweek 5  Sat  Away      D  2.0  2.0
#           9  2020-10-24  20:00   Matchweek 6  Sat  Home      W  2.0  1.0
#           11 2020-10-31  17:30   Matchweek 7  Sat  Home      W  2.0  1.0
#           13 2020-11-08  16:30   Matchweek 8  Sun  Away      D  1.0  1.0
#           14 2020-11-22  19:15   Matchweek 9  Sun  Home      W  3.0  0.0
#           16 2020-11-28  12:30  Matchweek 10  Sat  Away      D  1.0  1.0
#           18 2020-12-06  19:15  Matchweek 11  Sun  Home      W  4.0  0.0
#           20 2020-12-13  16:30  Matchweek 12  Sun  Away      D  1.0  1.0
#           21 2020-12-16  20:00  Matchweek 13  Wed  Home      W  2.0  1.0
#           22 2020-12-19  12:30  Matchweek 14  Sat  Away      W  7.0  0.0
#           23 2020-12-27  16:30  Matchweek 15  Sun  Home      D  1.0  1.0
#           24 2020-12-30  20:00  Matchweek 16  Wed  Away      D  0.0  0.0
#           25 2021-01-04  20:00  Matchweek 17  Mon  Away      L  0.0  1.0
#           27 2021-01-17  16:30  Matchweek 19  Sun  Home      D  0.0  0.0
#           28 2021-01-21  20:00  Matchweek 18  Thu  Home      L  0.0  1.0
#           30 2021-01-28  20:00  Matchweek 20  Thu  Away      W  3.0  1.0
#           31 2021-01-31  16:30  Matchweek 21  Sun  Away      W  3.0  1.0
#           32 2021-02-03  20:15  Matchweek 22  Wed  Home      L  0.0  1.0
#           33 2021-02-07  16:30  Matchweek 23  Sun  Home      L  1.0  4.0
#           34 2021-02-13  12:30  Matchweek 24  Sat  Away      L  1.0  3.0
#           36 2021-02-20  17:30  Matchweek 25  Sat  Home      L  0.0  2.0
#           37 2021-02-28  19:15  Matchweek 26  Sun  Away      W  2.0  0.0
#           38 2021-03-04  20:15  Matchweek 29  Thu  Home      L  0.0  1.0
#           39 2021-03-07  14:00  Matchweek 27  Sun  Home      L  0.0  1.0
#           41 2021-03-15  20:00  Matchweek 28  Mon  Away      W  1.0  0.0
#           42 2021-04-03  20:00  Matchweek 30  Sat  Away      W  3.0  0.0
#           44 2021-04-10  15:00  Matchweek 31  Sat  Home      W  2.0  1.0
#           46 2021-04-19  20:00  Matchweek 32  Mon  Away      D  1.0  1.0
#           47 2021-04-24  12:30  Matchweek 33  Sat  Home      D  1.0  1.0
#           48 2021-05-08  20:15  Matchweek 35  Sat  Home      W  2.0  0.0
#           49 2021-05-13  20:15  Matchweek 34  Thu  Away      W  4.0  2.0
#           50 2021-05-16  16:30  Matchweek 36  Sun  Away      W  2.0  1.0
#           51 2021-05-19  20:15  Matchweek 37  Wed  Away      W  3.0  0.0
#           52 2021-05-23  16:00  Matchweek 38  Sun  Home      W  2.0  0.0
#
#                      opponent   xg  ...  opp_code  hour  day_code gf_rolling  \
# team                                ...
# Liverpool 6       Aston Villa  1.8  ...         1    19         6   3.000000
#           7           Everton  2.2  ...         7    12         5   2.333333
#           9     Sheffield Utd  2.5  ...        16    20         5   2.333333
#           11         West Ham  1.8  ...        21    17         5   2.000000
#           13  Manchester City  1.4  ...        12    16         6   2.000000
#           14   Leicester City  3.7  ...        10    19         6   1.666667
#           16         Brighton  0.5  ...         3    12         5   2.000000
#           18           Wolves  1.2  ...        22    19         6   1.666667
#           20           Fulham  2.1  ...         8    16         6   2.666667
#           21        Tottenham  1.2  ...        18    20         2   2.000000
#           22   Crystal Palace  2.1  ...         6    12         5   2.333333
#           23        West Brom  1.6  ...        20    16         6   3.333333
#           24    Newcastle Utd  1.1  ...        14    20         2   3.333333
#           25      Southampton  1.1  ...        17    20         0   2.666667
#           27   Manchester Utd  1.7  ...        13    16         6   0.333333
#           28          Burnley  2.3  ...         4    20         3   0.000000
#           30        Tottenham  2.1  ...        18    20         3   0.000000
#           31         West Ham  1.9  ...        21    16         6   1.000000
#           32         Brighton  0.7  ...         3    20         2   2.000000
#           33  Manchester City  1.3  ...        12    16         6   2.000000
#           34   Leicester City  1.8  ...        10    12         5   1.333333
#           36          Everton  1.7  ...         7    17         5   0.666667
#           37    Sheffield Utd  2.9  ...        16    19         6   0.666667
#           38          Chelsea  0.3  ...         5    20         3   1.000000
#           39           Fulham  1.0  ...         8    14         6   0.666667
#           41           Wolves  1.1  ...        22    20         0   0.666667
#           42          Arsenal  2.2  ...         0    20         5   0.333333
#           44      Aston Villa  2.5  ...         1    15         5   1.333333
#           46     Leeds United  2.3  ...         9    20         0   2.000000
#           47    Newcastle Utd  1.9  ...        14    12         5   2.000000
#           48      Southampton  2.2  ...        17    20         5   1.333333
#           49   Manchester Utd  2.6  ...        13    20         3   1.333333
#           50        West Brom  2.4  ...        20    16         6   2.333333
#           51          Burnley  2.9  ...         4    20         2   2.666667
#           52   Crystal Palace  1.8  ...         6    16         6   3.000000
#
#              ga_rolling sh_rolling sot_rolling  fk_rolling  pk_rolling  \
# team
# Liverpool 6    1.333333  19.333333    6.000000    0.333333    0.666667
#           7    2.666667  17.333333    7.333333    0.666667    0.000000
#           9    3.333333  19.000000    8.333333    0.666667    0.000000
#           11   3.333333  17.666667    7.000000    1.000000    0.000000
#           13   1.333333  15.666667    5.000000    1.000000    0.333333
#           14   1.000000  11.333333    3.000000    0.666667    0.666667
#           16   0.666667  13.666667    5.333333    0.333333    0.666667
#           18   0.666667  13.000000    5.333333    0.000000    0.333333
#           20   0.333333  13.666667    6.666667    0.333333    0.000000
#           21   0.666667   9.333333    4.333333    0.666667    0.333333
#           22   0.666667  13.000000    7.333333    0.666667    0.333333
#           23   0.666667  14.000000    7.666667    0.666667    0.333333
#           24   0.666667  16.000000    6.666667    1.000000    0.000000
#           25   0.333333  14.000000    4.333333    1.000000    0.000000
#           27   0.666667  15.000000    2.333333    0.666667    0.000000
#           28   0.333333  15.000000    2.666667    0.000000    0.000000
#           30   0.666667  20.333333    3.333333    0.000000    0.000000
#           31   0.666667  19.333333    5.333333    0.000000    0.000000
#           32   1.000000  18.333333    6.000000    0.000000    0.000000
#           33   1.000000  13.000000    4.000000    0.000000    0.000000
#           34   2.000000  10.666667    2.333333    0.333333    0.333333
#           36   2.666667  11.000000    2.000000    1.000000    0.333333
#           37   3.000000  12.666667    4.000000    1.333333    0.333333
#           38   1.666667  15.333333    6.000000    1.000000    0.000000
#           39   1.000000  12.666667    5.000000    0.333333    0.000000
#           41   0.666667  12.666667    4.000000    0.333333    0.000000
#           42   0.666667  11.666667    2.666667    0.333333    0.000000
#           44   0.333333  14.666667    4.666667    0.333333    0.000000
#           46   0.333333  17.000000    6.333333    0.333333    0.000000
#           47   0.666667  18.666667    7.333333    0.333333    0.000000
#           48   1.000000  20.333333    8.000000    0.666667    0.000000
#           49   0.666667  17.333333    7.333333    0.333333    0.000000
#           50   1.000000  17.333333    7.666667    0.333333    0.000000
#           51   1.000000  19.000000    6.666667    0.333333    0.000000
#           52   1.000000  21.000000    5.666667    0.666667    0.000000
#
#               pkatt_rolling
# team
# Liverpool 6        0.666667
#           7        0.000000
#           9        0.000000
#           11       0.000000
#           13       0.333333
#           14       0.666667
#           16       0.666667
#           18       0.333333
#           20       0.000000
#           21       0.333333
#           22       0.333333
#           23       0.333333
#           24       0.000000
#           25       0.000000
#           27       0.000000
#           28       0.000000
#           30       0.000000
#           31       0.000000
#           32       0.000000
#           33       0.000000
#           34       0.333333
#           36       0.333333
#           37       0.333333
#           38       0.000000
#           39       0.000000
#           41       0.000000
#           42       0.000000
#           44       0.000000
#           46       0.000000
#           47       0.000000
#           48       0.000000
#           49       0.000000
#           50       0.000000
#           51       0.000000
#           52       0.000000
#
# [35 rows x 37 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time         round  day venue result   gf   ga  \
# 0    2020-10-04  14:00   Matchweek 4  Sun  Home      W  2.0  1.0
# 1    2020-10-17  17:30   Matchweek 5  Sat  Away      L  0.0  1.0
# 2    2020-10-25  19:15   Matchweek 6  Sun  Home      L  0.0  1.0
# 3    2020-11-01  16:30   Matchweek 7  Sun  Away      W  1.0  0.0
# 4    2020-11-08  19:15   Matchweek 8  Sun  Home      L  0.0  3.0
# ...         ...    ...           ...  ...   ...    ...  ...  ...
# 1315 2022-03-13  14:00  Matchweek 29  Sun  Away      W  1.0  0.0
# 1316 2022-03-18  20:00  Matchweek 30  Fri  Home      L  2.0  3.0
# 1317 2022-04-02  15:00  Matchweek 31  Sat  Home      W  2.0  1.0
# 1318 2022-04-08  20:00  Matchweek 32  Fri  Away      L  0.0  1.0
# 1319 2022-04-24  14:00  Matchweek 34  Sun  Away      L  0.0  1.0
#
#              opponent   xg  ...  opp_code  hour  day_code gf_rolling  \
# 0       Sheffield Utd  0.4  ...        16    14         6   2.000000
# 1     Manchester City  0.9  ...        12    17         5   1.666667
# 2      Leicester City  0.9  ...        10    19         6   1.000000
# 3      Manchester Utd  1.1  ...        13    16         6   0.666667
# 4         Aston Villa  1.5  ...         1    19         6   0.333333
# ...               ...  ...  ...       ...   ...       ...        ...
# 1315          Everton  0.8  ...         7    14         6   1.333333
# 1316     Leeds United  0.8  ...         9    20         4   1.666667
# 1317      Aston Villa  1.2  ...         1    15         5   2.333333
# 1318    Newcastle Utd  0.3  ...        14    20         4   1.666667
# 1319          Burnley  0.7  ...         4    14         6   1.333333
#
#      ga_rolling sh_rolling sot_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 0      1.333333   7.666667    3.666667    0.666667    0.000000       0.000000
# 1      1.666667   5.333333    3.666667    0.000000    0.000000       0.000000
# 2      1.666667   7.000000    3.666667    0.666667    0.000000       0.000000
# 3      1.000000   9.666667    4.000000    1.000000    0.000000       0.000000
# 4      0.666667   9.666667    2.666667    1.000000    0.333333       0.333333
# ...         ...        ...         ...         ...         ...            ...
# 1315   1.000000  12.333333    3.666667    0.000000    0.000000       0.000000
# 1316   0.666667  12.333333    4.333333    0.000000    0.000000       0.000000
# 1317   1.000000  13.000000    5.333333    0.000000    0.000000       0.000000
# 1318   1.333333  13.000000    5.000000    0.000000    0.000000       0.000000
# 1319   1.666667  10.000000    4.666667    0.000000    0.000000       0.000000
#
# [1320 rows x 37 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)
precision
# Out:
# 0.5344827586206896

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
dummy = combined[combined['team']=='Brentford']
dummy
# Out:
#      actual  predicted       date       team         opponent result
# 150       1          0 2022-01-02  Brentford      Aston Villa      W
# 151       0          0 2022-01-11  Brentford      Southampton      L
# 152       0          0 2022-01-16  Brentford        Liverpool      L
# 153       0          0 2022-01-19  Brentford   Manchester Utd      L
# 154       0          0 2022-01-22  Brentford           Wolves      L
# 155       0          0 2022-02-09  Brentford  Manchester City      L
# 156       0          0 2022-02-12  Brentford   Crystal Palace      D
# 157       0          0 2022-02-19  Brentford          Arsenal      L
# 158       0          0 2022-02-26  Brentford    Newcastle Utd      L
# 159       1          0 2022-03-05  Brentford     Norwich City      W
# 160       1          0 2022-03-12  Brentford          Burnley      W
# 161       0          0 2022-03-20  Brentford   Leicester City      L
# 162       1          0 2022-04-02  Brentford          Chelsea      W
# 163       1          1 2022-04-10  Brentford         West Ham      W
# 164       1          0 2022-04-16  Brentford          Watford      W
# 165       0          1 2022-04-23  Brentford        Tottenham      D

# %%
len(dummy)
# Out:
# 16

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('accuracy.csv')

# %%
df = df.sort_values('Accuracy Score',ascending=True)

accuracy = list(df['Accuracy Score'])
team = list(df['Team Name'])

# %%
plt.figure(figsize=(12,10))
plt.barh(team,accuracy,edgecolor='white',linewidth=2)
plt.title('Accuracy of Model for each Premier League Team',fontproperties=prop,fontsize=18)
plt.xlabel('Accuracy Score(%)',fontproperties=prop,fontsize=20)
plt.yticks(fontproperties=prop,rotation=0,fontsize=15)
plt.xticks(fontproperties=prop,fontsize=15)
plt.grid()

# %%
df_corr = pd.read_csv('correlation.csv')

# %%
df_corr = df_corr.dropna()

# %%
accuracy_score = df_corr['Accuracy Score']
league_position = df_corr['League Position']

# %%
plt.figure(figsize=(11,10))
plt.plot(accuracy_score,league_position,'o',color='white')
plt.title('Correlation between Accuracy Score and League Position from 21/22 Season',fontproperties=prop,fontsize=17)
plt.xlabel('Accuracy Score(%)',fontproperties=prop,fontsize=17)
plt.ylabel('League Position',fontproperties=prop,fontsize=17)
plt.yticks(fontproperties=prop,rotation=0,fontsize=15)
plt.xticks(fontproperties=prop,fontsize=15)
plt.yticks(np.arange(2,20,5),fontproperties=prop,fontsize=15)
plt.axvline(x=63.5, color="white", linestyle="--")
plt.text(60,18,'Median',fontproperties=prop,fontsize=16,color='white')
plt.axhline(y=9.5, color="white", linestyle="--")
plt.text(50,9,'Average',fontproperties=prop,fontsize=16,color='white')
plt.gca().invert_yaxis()
plt.scatter(50,1,s=350,color='#6cabdd')
plt.text(51,1,'Man City',fontproperties=prop,fontsize=15,color='#6cabdd')
plt.scatter(52,2,s=350,color='#c8102e')
plt.text(53,2.1,'Liverpool',fontproperties=prop,fontsize=15,color='#c8102e')
plt.scatter(58,3,s=350,color='#034694')
plt.text(59,3,'Chelsea',fontproperties=prop,fontsize=15,color='#034694')
plt.scatter(53,4,s=350,color='#ffffff',alpha=0.7)
plt.text(54,4.2,'Spurs',fontproperties=prop,fontsize=15,color='#ffffff')
plt.scatter(71,18,s=350,color='#6c1d45')
plt.text(71.8,18,'Burnley',fontproperties=prop,fontsize=15,color='#6c1d45')
plt.scatter(67,17,s=350,color='#ffffff',alpha=0.7)
plt.text(67,16.5,'Leeds Utd',fontproperties=prop,fontsize=15,color='#ffffff')
plt.scatter(73,16,s=350,color='#003399')
plt.text(73.5,16,'Everton',fontproperties=prop,fontsize=15,color='#003090')
plt.scatter(79,14,s=350,color='#6c1d45')
plt.text(74.5,14,'Aston Villa',fontproperties=prop,fontsize=15,color='#6c1d45')
plt.grid()
plt.savefig("CMSE202Plot.png",dpi=900)
